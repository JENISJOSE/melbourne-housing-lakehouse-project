# %%
# df = spark.table("default.melb_data")
# df.show(5)
# df.printSchema()
# df.count()
# df.columns
# df.select("Suburb", "Price").show(10)
# df.filter(df.Price > 1000000).show(10)
# df.orderBy(df.Price.desc()).show(10)
# from pyspark.sql.functions import avg

# df.groupBy("Suburb") \
#   .agg(avg("Price").alias("avg_price")) \
#   .orderBy("avg_price", ascending=False) \
#   .show(10)
# df.write \
#   .format("delta") \
#   .mode("overwrite") \
#   .saveAsTable("default.bronze_melb_housing")
# df.printSchema()

bronze_df = spark.table("default.bronze_melb_housing")

bronze_df.show(5)
# Out:
# +----------+----------------+-----+----+---------+------+-------+----------+--------+--------+--------+--------+---+--------+------------+---------+-----------+---------+----------+--------------------+-------------+
# |    Suburb|         Address|Rooms|Type|    Price|Method|SellerG|      Date|Distance|Postcode|Bedroom2|Bathroom|Car|Landsize|BuildingArea|YearBuilt|CouncilArea|Lattitude|Longtitude|          Regionname|Propertycount|
# +----------+----------------+-----+----+---------+------+-------+----------+--------+--------+--------+--------+---+--------+------------+---------+-----------+---------+----------+--------------------+-------------+
# |Abbotsford|    85 Turner St|    2|   h|1480000.0|     S| Biggin|2016-12-03|     2.5|  3067.0|     2.0|     1.0|1.0|   202.0|        NULL|     NULL|      Yarra| -37.7996|  144.9984|Northern Metropol...|       4019.0|
# |Abbotsford| 25 Bloomburg St|    2|   h|1035000.0|     S| Biggin|2016-02-04|     2.5|  3067.0|     2.0|     1.0|0.0|   156.0|        79.0|   1900.0|      Yarra| -37.8079|  144.9934|Northern Metropol...|       4019.0|
# |Abbotsford|    5 Charles St|    3|   h|1465000.0|    SP| Biggin|2017-03-04|     2.5|  3067.0|     3.0|     2.0|0.0|   134.0|       150.0|   1900.0|      Yarra| -37.8093|  144.9944|Northern Metropol...|       4019.0|
# |Abbotsford|40 Federation La|    3|   h| 850000.0|    PI| Biggin|2017-03-04|     2.5|  3067.0|     3.0|     2.0|1.0|    94.0|        NULL|     NULL|      Yarra| -37.7969|  144.9969|Northern Metropol...|       4019.0|
# |Abbotsford|     55a Park St|    4|   h|1600000.0|    VB| Nelson|2016-06-04|     2.5|  3067.0|     3.0|     1.0|2.0|   120.0|       142.0|   2014.0|      Yarra| -37.8072|  144.9941|Northern Metropol...|       4019.0|
# +----------+----------------+-----+----+---------+------+-------+----------+--------+--------+--------+--------+---+--------+------------+---------+-----------+---------+----------+--------------------+-------------+
# only showing top 5 rows
